# %% [markdown]
# ### The Matlab or Octave or Python function “freqz” (we have a Python freqz function also in Moodle) can be used to plot the magnitude and phase plot of the transfer function of this filter. Its input are directly the coefficients a and b of the transfer function H(z), in the form:
# ### $$ freqz(B,A),$$
# ### If we choose $a(1)=p=0.9$ in our example, we obtain

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from freqz import freqz
import numpy as np

# %%
A = [1, -0.9]
B = [1]
w = freqz(B, A) #w, h = freqz(B,A)
print len(w)
# Out:
# 512

# %% [markdown]
# Observe that the horizontal axis is the normalized frequency (see last lecture), its right hand side is pi, which is the Nyquist frequency or half the sampling frequency. The frequency response we see here has a low pass characteristic.

# %% [markdown]
# We can use the command “zplane” (also in Moodle) to plot the location of the zeros and poles in the complex z-plane, with
# from zplane import zplane
# zplane(B,A)

# %%
from zplane import zplane 
zplane(B,A)
# Out:
# ()

# %% [markdown]
# Zeros are marked with an “o”, and poles are marked with an “x”. Here we see the pole at location z=0.9.
